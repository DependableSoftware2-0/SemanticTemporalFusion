# %% [markdown]
# # Library
#
# ## Segmentation models
#
# Using oxford cat  dog dataset
#
# https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/binary_segmentation_intro.ipynb

# %%
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
# !pip install pytorch-lightning==1.5.4
# !pip install ipywidgets
# !pip install tqdm
# Out:
# Collecting git+https://github.com/qubvel/segmentation_models.pytorch
#   Cloning https://github.com/qubvel/segmentation_models.pytorch to /tmp/pip-req-build-ig2oaumi
#   Running command git clone -q https://github.com/qubvel/segmentation_models.pytorch /tmp/pip-req-build-ig2oaumi
#   Resolved https://github.com/qubvel/segmentation_models.pytorch to commit 8bf52c7e862af006e76a23aae6aa17977d7f9a79
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: torchvision>=0.5.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from segmentation-models-pytorch==0.3.0.dev0) (0.11.3)
# Requirement already satisfied: pillow in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from segmentation-models-pytorch==0.3.0.dev0) (8.4.0)
# Requirement already satisfied: efficientnet-pytorch==0.6.3 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from segmentation-models-pytorch==0.3.0.dev0) (0.6.3)
# Requirement already satisfied: pretrainedmodels==0.7.4 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from segmentation-models-pytorch==0.3.0.dev0) (0.7.4)
# Requirement already satisfied: tqdm in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from segmentation-models-pytorch==0.3.0.dev0) (4.60.0)
# Requirement already satisfied: timm==0.4.12 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from segmentation-models-pytorch==0.3.0.dev0) (0.4.12)
# Requirement already satisfied: torch in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from efficientnet-pytorch==0.6.3->segmentation-models-pytorch==0.3.0.dev0) (1.10.2)
# Requirement already satisfied: munch in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch==0.3.0.dev0) (2.5.0)
# Requirement already satisfied: typing_extensions in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from torch->efficientnet-pytorch==0.6.3->segmentation-models-pytorch==0.3.0.dev0) (3.10.0.2)
# Requirement already satisfied: numpy in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from torchvision>=0.5.0->segmentation-models-pytorch==0.3.0.dev0) (1.21.2)
# Requirement already satisfied: six in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch==0.3.0.dev0) (1.16.0)
# Building wheels for collected packages: segmentation-models-pytorch
#   Building wheel for segmentation-models-pytorch (PEP 517) ... done
#   Created wheel for segmentation-models-pytorch: filename=segmentation_models_pytorch-0.3.0.dev0-py3-none-any.whl size=98008 sha256=9b355270233468215289aab48698c8b800332bf817094b1330ad7adb56e3abea
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y5b6bltr/wheels/18/f6/12/bdbad33e766c5fddfa996bfb2545d31ca070438d37e5b76408
# Successfully built segmentation-models-pytorch
# Installing collected packages: segmentation-models-pytorch
#   Attempting uninstall: segmentation-models-pytorch
#     Found existing installation: segmentation-models-pytorch 0.2.1
#     Uninstalling segmentation-models-pytorch-0.2.1:
#       Successfully uninstalled segmentation-models-pytorch-0.2.1
# Successfully installed segmentation-models-pytorch-0.3.0.dev0
# Requirement already satisfied: pytorch-lightning==1.5.4 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (1.5.4)
# Requirement already satisfied: torch>=1.7.* in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning==1.5.4) (1.10.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning==1.5.4) (2.8.0)
# Requirement already satisfied: future>=0.17.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning==1.5.4) (0.18.2)
# Requirement already satisfied: numpy>=1.17.2 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning==1.5.4) (1.21.2)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning==1.5.4) (2022.2.0)
# Requirement already satisfied: typing-extensions in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning==1.5.4) (3.10.0.2)
# Requirement already satisfied: PyYAML>=5.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning==1.5.4) (6.0)
# Requirement already satisfied: packaging>=17.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning==1.5.4) (21.3)
# Requirement already satisfied: tqdm>=4.41.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning==1.5.4) (4.60.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning==1.5.4) (0.7.2)
# Requirement already satisfied: pyDeprecate==0.3.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pytorch-lightning==1.5.4) (0.3.1)
# Requirement already satisfied: requests in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (2.27.1)
# Requirement already satisfied: aiohttp in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from packaging>=17.0->pytorch-lightning==1.5.4) (3.0.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.4) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.4) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.4) (0.37.1)
# Requirement already satisfied: grpcio>=1.24.3 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.4) (1.42.0)
# Requirement already satisfied: protobuf>=3.6.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.4) (3.19.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.4) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.4) (2.0.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.4) (58.0.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.4) (0.6.1)
# Requirement already satisfied: absl-py>=0.4 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.4) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.4) (3.3.6)
# Requirement already satisfied: six in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch-lightning==1.5.4) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.4) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.4) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.4) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.5.4) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.5.4) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.5.4) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.4) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.5.4) (3.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.4) (1.2.0)
# Requirement already satisfied: ipywidgets in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (7.6.5)
# Requirement already satisfied: nbformat>=4.2.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipywidgets) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: traitlets>=4.3.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipywidgets) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipywidgets) (7.31.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipywidgets) (1.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipywidgets) (6.4.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: decorator in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pickleshare in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: backcall in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pygments in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (2.10.0)
# Requirement already satisfied: pexpect>4.3 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets) (58.0.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.1)
# Requirement already satisfied: entrypoints in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (0.3)
# Requirement already satisfied: pyzmq>=13 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: six>=1.11.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.4.8)
# Requirement already satisfied: terminado>=0.8.3 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: prometheus-client in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.13.1)
# Requirement already satisfied: jinja2 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.8.0)
# Requirement already satisfied: nbconvert in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.3.0)
# Requirement already satisfied: argon2-cffi in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pycparser in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.11)
# Requirement already satisfied: testpath in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: defusedxml in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.7.1)
# Requirement already satisfied: bleach in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: webencodings in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.0.7)
# Requirement already satisfied: tqdm in /home/deebuls/miniconda3/envs/pytorch/lib/python3.9/site-packages (4.60.0)

# %%
import os
import torch
import shutil
import numpy as np

from PIL import Image
from tqdm import tqdm
from urllib.request import urlretrieve


class OxfordPetDataset(torch.utils.data.Dataset):
    def __init__(self, root, mode="train", transform=None):

        assert mode in {"train", "valid", "test"}

        self.root = root
        self.mode = mode
        self.transform = transform

        self.images_directory = os.path.join(self.root, "images")
        self.masks_directory = os.path.join(self.root, "annotations", "trimaps")

        self.filenames = self._read_split()  # read train/valid/test splits

    def __len__(self):
        return len(self.filenames)

    def __getitem__(self, idx):

        filename = self.filenames[idx]
        image_path = os.path.join(self.images_directory, filename + ".jpg")
        mask_path = os.path.join(self.masks_directory, filename + ".png")

        image = np.array(Image.open(image_path).convert("RGB"))

        trimap = np.array(Image.open(mask_path))
        mask = self._preprocess_mask(trimap)

        sample = dict(image=image, mask=mask, trimap=trimap)
        if self.transform is not None:
            sample = self.transform(**sample)

        return sample

    @staticmethod
    def _preprocess_mask(mask):
        mask = mask.astype(np.float32)
        mask[mask == 2.0] = 0.0
        mask[(mask == 1.0) | (mask == 3.0)] = 1.0
        return mask

    def _read_split(self):
        split_filename = "test.txt" if self.mode == "test" else "trainval.txt"
        split_filepath = os.path.join(self.root, "annotations", split_filename)
        with open(split_filepath) as f:
            split_data = f.read().strip("\n").split("\n")
        filenames = [x.split(" ")[0] for x in split_data]
        if self.mode == "train":  # 90% for train
            filenames = [x for i, x in enumerate(filenames) if i % 10 != 0]
        elif self.mode == "valid":  # 10% for validation
            filenames = [x for i, x in enumerate(filenames) if i % 10 == 0]
        return filenames

    @staticmethod
    def download(root):

        # load images
        filepath = os.path.join(root, "images.tar.gz")
        download_url(
            url="https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz",
            filepath=filepath,
        )
        extract_archive(filepath)

        # load annotations
        #filepath = os.path.join(root, "annotations.tar.gz")
        #download_url(
        #    url="https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz",
        #    filepath=filepath,
        #)
        #extract_archive(filepath)


class SimpleOxfordPetDataset(OxfordPetDataset):
    def __getitem__(self, *args, **kwargs):

        sample = super().__getitem__(*args, **kwargs)

        # resize images
        image = np.array(Image.fromarray(sample["image"]).resize((256, 256), Image.LINEAR))
        mask = np.array(Image.fromarray(sample["mask"]).resize((256, 256), Image.NEAREST))
        trimap = np.array(Image.fromarray(sample["trimap"]).resize((256, 256), Image.NEAREST))

        # convert to other format HWC -> CHW
        sample["image"] = np.moveaxis(image, -1, 0)
        sample["mask"] = np.expand_dims(mask, 0)
        sample["trimap"] = np.expand_dims(trimap, 0)

        return sample


class TqdmUpTo(tqdm):
    def update_to(self, b=1, bsize=1, tsize=None):
        if tsize is not None:
            self.total = tsize
        self.update(b * bsize - self.n)


def download_url(url, filepath):
    directory = os.path.dirname(os.path.abspath(filepath))
    os.makedirs(directory, exist_ok=True)
    if os.path.exists(filepath):
        return

    with TqdmUpTo(
        unit="B",
        unit_scale=True,
        unit_divisor=1024,
        miniters=1,
        desc=os.path.basename(filepath),
    ) as t:
        urlretrieve(url, filename=filepath, reporthook=t.update_to, data=None)
        t.total = t.n


def extract_archive(filepath):
    extract_dir = os.path.dirname(os.path.abspath(filepath))
    dst_dir = os.path.splitext(filepath)[0]
    if not os.path.exists(dst_dir):
        shutil.unpack_archive(filepath, extract_dir)

# %%
import os
import torch
import matplotlib.pyplot as plt
import pytorch_lightning as pl
import segmentation_models_pytorch as smp

from pprint import pprint
from torch.utils.data import DataLoader

# %%
root = '.'
# init train, val, test sets
train_dataset = SimpleOxfordPetDataset(root, "train")
valid_dataset = SimpleOxfordPetDataset(root, "valid")
test_dataset = SimpleOxfordPetDataset(root, "test")

# It is a good practice to check datasets don`t intersects with each other
assert set(test_dataset.filenames).isdisjoint(set(train_dataset.filenames))
assert set(test_dataset.filenames).isdisjoint(set(valid_dataset.filenames))
assert set(train_dataset.filenames).isdisjoint(set(valid_dataset.filenames))

print(f"Train size: {len(train_dataset)}")
print(f"Valid size: {len(valid_dataset)}")
print(f"Test size: {len(test_dataset)}")

n_cpu = os.cpu_count()
print (" CPU ", n_cpu)
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=int(n_cpu/2))
valid_dataloader = DataLoader(valid_dataset, batch_size=16, shuffle=False, num_workers=int(n_cpu/2))
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False, num_workers=int(n_cpu/2))
# Out:
# Train size: 3312
# Valid size: 368
# Test size: 3669
#  CPU  16

# %%
# lets look at some samples

sample = train_dataset[0]
plt.subplot(1,2,1)
plt.imshow(sample["image"].transpose(1, 2, 0)) # for visualization we have to transpose back to HWC
plt.subplot(1,2,2)
plt.imshow(sample["mask"].squeeze())  # for visualization we have to remove 3rd dimension of mask
plt.show()

sample = valid_dataset[0]
plt.subplot(1,2,1)
plt.imshow(sample["image"].transpose(1, 2, 0)) # for visualization we have to transpose back to HWC
plt.subplot(1,2,2)
plt.imshow(sample["mask"].squeeze())  # for visualization we have to remove 3rd dimension of mask
plt.show()
print (sample["mask"].shape)
sample = test_dataset[0]
plt.subplot(1,2,1)
plt.imshow(sample["image"].transpose(1, 2, 0)) # for visualization we have to transpose back to HWC
plt.subplot(1,2,2)
plt.imshow(sample["mask"].squeeze())  # for visualization we have to remove 3rd dimension of mask
plt.show()
# Out:
# (1, 256, 256)

# %%
class PetModel(pl.LightningModule):

    def __init__(self, arch, encoder_name, in_channels, out_classes, **kwargs):
        super().__init__()
        self.model = smp.create_model(
            arch, encoder_name=encoder_name, in_channels=in_channels, classes=out_classes, **kwargs
        )

        # preprocessing parameteres for image
        params = smp.encoders.get_preprocessing_params(encoder_name)
        self.register_buffer("std", torch.tensor(params["std"]).view(1, 3, 1, 1))
        self.register_buffer("mean", torch.tensor(params["mean"]).view(1, 3, 1, 1))

        # for image segmentation dice loss could be the best first choice
        self.loss_fn = smp.losses.DiceLoss(smp.losses.BINARY_MODE, from_logits=True)

    def forward(self, image):
        # normalize image here
        image = (image - self.mean) / self.std
        mask = self.model(image)
        return mask

    def shared_step(self, batch, stage):
        
        image = batch["image"]

        # Shape of the image should be (batch_size, num_channels, height, width)
        # if you work with grayscale images, expand channels dim to have [batch_size, 1, height, width]
        assert image.ndim == 4

        # Check that image dimensions are divisible by 32, 
        # encoder and decoder connected by `skip connections` and usually encoder have 5 stages of 
        # downsampling by factor 2 (2 ^ 5 = 32); e.g. if we have image with shape 65x65 we will have 
        # following shapes of features in encoder and decoder: 84, 42, 21, 10, 5 -> 5, 10, 20, 40, 80
        # and we will get an error trying to concat these features
        h, w = image.shape[2:]
        assert h % 32 == 0 and w % 32 == 0

        mask = batch["mask"]

        # Shape of the mask should be [batch_size, num_classes, height, width]
        # for binary segmentation num_classes = 1
        assert mask.ndim == 4

        # Check that mask values in between 0 and 1, NOT 0 and 255 for binary segmentation
        assert mask.max() <= 1.0 and mask.min() >= 0

        logits_mask = self.forward(image)
        
        # Predicted mask contains logits, and loss_fn param `from_logits` is set to True
        loss = self.loss_fn(logits_mask, mask)

        # Lets compute metrics for some threshold
        # first convert mask values to probabilities, then 
        # apply thresholding
        prob_mask = logits_mask.sigmoid()
        pred_mask = (prob_mask > 0.5).float()

        # We will compute IoU metric by two ways
        #   1. dataset-wise
        #   2. image-wise
        # but for now we just compute true positive, false positive, false negative and
        # true negative 'pixels' for each image and class
        # these values will be aggregated in the end of an epoch
        tp, fp, fn, tn = smp.metrics.get_stats(pred_mask.long(), mask.long(), mode="binary")

        return {
            "loss": loss,
            "tp": tp,
            "fp": fp,
            "fn": fn,
            "tn": tn,
        }

    def shared_epoch_end(self, outputs, stage):
        # aggregate step metics
        tp = torch.cat([x["tp"] for x in outputs])
        fp = torch.cat([x["fp"] for x in outputs])
        fn = torch.cat([x["fn"] for x in outputs])
        tn = torch.cat([x["tn"] for x in outputs])

        # per image IoU means that we first calculate IoU score for each image 
        # and then compute mean over these scores
        per_image_iou = smp.metrics.iou_score(tp, fp, fn, tn, reduction="micro-imagewise")
        
        # dataset IoU means that we aggregate intersection and union over whole dataset
        # and then compute IoU score. The difference between dataset_iou and per_image_iou scores
        # in this particular case will not be much, however for dataset 
        # with "empty" images (images without target class) a large gap could be observed. 
        # Empty images influence a lot on per_image_iou and much less on dataset_iou.
        dataset_iou = smp.metrics.iou_score(tp, fp, fn, tn, reduction="micro")

        metrics = {
            f"{stage}_per_image_iou": per_image_iou,
            f"{stage}_dataset_iou": dataset_iou,
        }
        
        self.log_dict(metrics, prog_bar=True)

    def training_step(self, batch, batch_idx):
        return self.shared_step(batch, "train")            

    def training_epoch_end(self, outputs):
        return self.shared_epoch_end(outputs, "train")

    def validation_step(self, batch, batch_idx):
        return self.shared_step(batch, "valid")

    def validation_epoch_end(self, outputs):
        return self.shared_epoch_end(outputs, "valid")

    def test_step(self, batch, batch_idx):
        return self.shared_step(batch, "test")  

    def test_epoch_end(self, outputs):
        return self.shared_epoch_end(outputs, "test")

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=0.0001)

# %%
model = PetModel("FPN", "resnet34", in_channels=3, out_classes=1)

# %%
trainer = pl.Trainer(
    gpus=1, 
    max_epochs=50,
)

trainer.fit(
    model, 
    train_dataloaders=train_dataloader, 
    val_dataloaders=valid_dataloader,
)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type     | Params
# -------------------------------------
# 0 | model   | FPN      | 23.2 M
# 1 | loss_fn | DiceLoss | 0
# -------------------------------------
# 23.2 M    Trainable params
# 0         Non-trainable params
# 23.2 M    Total params
# 92.622    Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %%
# run validation dataset
valid_metrics = trainer.validate(model, dataloaders=valid_dataloader, verbose=False)
pprint(valid_metrics)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validating: 0it [00:00, ?it/s]
# [{'valid_dataset_iou': 0.9027100801467896,
#   'valid_per_image_iou': 0.8952273726463318}]

# %%
# run validation dataset
valid_metrics = trainer.validate(model, dataloaders=valid_dataloader, verbose=False)
pprint(valid_metrics)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validating: 0it [00:00, ?it/s]
# [{'valid_dataset_iou': 0.9027100801467896,
#   'valid_per_image_iou': 0.8952273726463318}]

# %%
batch = next(iter(test_dataloader))
with torch.no_grad():
    model.eval()
    logits = model(batch["image"])
pr_masks = logits.sigmoid()

for image, gt_mask, pr_mask in zip(batch["image"], batch["mask"], pr_masks):
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(image.numpy().transpose(1, 2, 0))  # convert CHW -> HWC
    plt.title("Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(gt_mask.numpy().squeeze()) # just squeeze classes dim, because we have only one class
    plt.title("Ground truth")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pr_mask.numpy().squeeze()) # just squeeze classes dim, because we have only one class
    plt.title("Prediction")
    plt.axis("off")

    plt.show()
