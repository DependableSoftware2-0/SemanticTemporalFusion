# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np
plt.figure()

fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(10, 8))

# Make data.
X = torch.arange(1, 10, 0.5)
Y = torch.arange(1, 10, 0.5)
X, Y = torch.meshgrid(X, Y)
x = torch.vstack((X.ravel(), Y.ravel())).T

Z = Dirichlet(x).entropy()
Z = Z.reshape(len(X), len(Y))

# Plot the surface.
surf = ax.plot_surface(X.cpu().numpy(), Y.cpu().numpy(), Z.cpu().numpy(), cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-2.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9166666666667">
# <img src="data:image/png;base64,..." width="999.8333333333334">

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np
plt.figure()

fig, ax = plt.subplots(figsize=(10, 8))

# Make data.
X = torch.arange(1, 10, 0.5)
Y = torch.arange(1, 10, 0.5)
X, Y = torch.meshgrid(X, Y)
x = torch.vstack((X.ravel(), Y.ravel())).T

Z = Dirichlet(x).entropy()
Z = Z.reshape(len(X), len(Y))
  
# show image
shw = ax.imshow(Z)
  
# make bar
bar = plt.colorbar(shw)

bar.set_label('ColorBar')
plt.show()

plt.show()

# %%
Z.min().item()
# Out:
# -1.3565540313720703

# %%
Z.max().item()
# Out:
# 0.0

# %%
np.arange(Z.min().item(),Z.max().item(), 0. ).tolist()
# Out:
# [-1.3565540313720703,
#  -1.1565540313720704,
#  -0.9565540313720704,
#  -0.7565540313720704,
#  -0.5565540313720705,
#  -0.35655403137207053,
#  -0.15655403137207058]
